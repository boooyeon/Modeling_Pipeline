# %% [markdown]
# ### Netflix EDA
# - 아래의 서비스에서 데이터를 수집하여 EDA를 수행하세요.
#
#
# - flixpatrol 사이트에서 데이터 수집
#     - `https://flixpatrol.com/top10/netflix/world/2021/full/#netflix-1`
#
#
# - kaggle에서 netflix 컨텐츠 데이터 수집
#     - `https://www.kaggle.com/shivamb/netflix-shows`
#
#
# - 컨텐츠의 등급데이터는 아래의 코드 사용
# ```
# ratings_ages = {'TV-PG': 'Older Kids', 'TV-MA': 'Adults', 'TV-Y7-FV': 'Older Kids',
#                   'TV-Y7': 'Older Kids', 'TV-14': 'Teens', 'R': 'Adults', 'TV-Y': 'Kids',
#                   'NR': 'Adults', 'PG-13': 'Teens', 'TV-G': 'Kids', 'PG': 'Older Kids',
#                   'G': 'Kids', 'UR': 'Adults', 'NC-17': 'Adults'}
# ```

# %% [markdown]
# #### EDA의 수행 절차
# - 데이터 수집
# - 결측 데이터의 처리
# - 데이터 탐색
#     - 수집한 데이터에서 자유롭게 주제를 선정하여 데이터 분석을 통한 인사이트 도출
#     - 예시 : 인도영화는 다른 국가보다 러닝타임이 길것이다. 컨텐츠의 퀄리티가 가장 좋은 국가는?

# %% [markdown]
# #### 컨텐츠 타입과 컨텐츠 등급별 컨텐츠의 비율

# %%
# 아래의 코드는 EDA의 예시를 보여주는 것으로 실제 코드가 동작되지 않습니다.

plt.figure(figsize=(20, 5))

plt.subplot(121)
plt.title("Movie")
plt.pie(movie_count.values, labels=movie_count.index, autopct="%1.1f%%")

plt.subplot(122)
plt.title("TV Show")
plt.pie(tv_count.values, labels=tv_count.index, autopct="%1.1f%%")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb Cell 4' in <module>
#       <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000003?line=0'>1</a> # 아래의 코드는 EDA의 예시를 보여주는 것으로 실제 코드가 동작되지 않습니다.
# ----> <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000003?line=2'>3</a> plt.figure(figsize=(20, 5))
#       <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000003?line=4'>5</a> plt.subplot(121)
#       <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000003?line=5'>6</a> plt.title("Movie")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# 결론 : 영화가 TV쇼 보다 청소년 관람불가 등급의 비율이 더 높고 TV가 영화보다 청소년관람등급의 컨텐츠의 비율이 더 높습니다.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
country = "world"
url = f'https://flixpatrol.com/top10/netflix/{country}/2021/full/#netflix-1'
response = requests.get(url)
dom = BeautifulSoup(response.text, "html.parser")

# %%
movies = dom.select("#netflix-1 > div.-mx-content > div > div > table > tbody > tr.table-group > td")
tvs = dom.select("#netflix-2 > div.-mx-content > div > div > table > tbody > tr.table-group > td")

movie = []


data = {
    "rank" : 0,
    "title" : 0,
    "point" : 0,
    "day" : 0,
    "country" : 0,
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb Cell 8' in <module>
#       <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=3'>4</a> movie = []
#       <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=5'>6</a> for i in movies :
# ----> <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=6'>7</a>    i.select_one("a").text
#      <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=9'>10</a> data = {
#      <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=10'>11</a>     "rank" : 0,
#      <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=11'>12</a>     "title" : 0,
#    (...)
#      <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=14'>15</a>     "country" : 0,
#      <a href='vscode-notebook-cell:/Users/kdh/Desktop/web-crawling/01_netflix_project.ipynb#ch0000008?line=15'>16</a> }
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
cols = ['show_id', 'type', 'title', 'release_year', 'rating', 'duration', 'listed_in',]
netflix = pd.read_csv("./netflix_titles.csv", usecols=cols)

netflix.loc[netflix["title"] == "Notice"]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, release_year, rating, duration, listed_in]
# Index: []

# %%
netflix.loc[netflix["rating"]]

# %%
movies = pd.DataFrame(movies_titles)
tvs = pd.DataFrame(tvs_titles)

# %%
movies["title"] = movies
tvs["title"] = tvs

# %%
movies.drop(0, axis=1, inplace=True)
tvs.drop(0, axis=1, inplace=True)

# %%
netflix.merge(movies)
# Out:
#    show_id   type                                    title  release_year  \
# 0       s7  Movie         My Little Pony: A New Generation          2021
# 1      s10  Movie                             The Starling          2021
# 2      s19  Movie                                Intrusion          2021
# 3      s36  Movie           The Father Who Moves Mountains          2021
# 4      s37  Movie                           The Stronghold          2021
# ..     ...    ...                                      ...           ...
# 84   s7890  Movie                                     Room          2015
# 85   s7903  Movie                                      Run          2004
# 86   s8184  Movie  The Adventures of Sharkboy and Lavagirl          2005
# 87   s8259  Movie                               The Croods          2013
# 88   s8502  Movie                The Secret Life of Pets 2          2019
#
#    rating duration                                          listed_in
# 0      PG   91 min                           Children & Family Movies
# 1   PG-13  104 min                                   Comedies, Dramas
# 2   TV-14   94 min                                          Thrillers
# 3   TV-MA  110 min            Dramas, International Movies, Thrillers
# 4   TV-MA  105 min   Action & Adventure, Dramas, International Movies
# ..    ...      ...                                                ...
# 84      R  118 min                         Dramas, Independent Movies
# 85  TV-14  134 min  Action & Adventure, International Movies, Musi...
# 86     PG   93 min                           Children & Family Movies
# 87     PG   99 min                 Children & Family Movies, Comedies
# 88     PG   86 min                 Children & Family Movies, Comedies
#
# [89 rows x 7 columns]

# %%
netflix.merge(tvs)
# Out:
#     show_id     type                   title  release_year rating    duration  \
# 0        s6  TV Show           Midnight Mass          2021  TV-MA    1 Season
# 1       s22  TV Show  Resurrection: Ertugrul          2018  TV-14   5 Seasons
# 2       s33  TV Show           Sex Education          2020  TV-MA   3 Seasons
# 3       s34  TV Show              Squid Game          2021  TV-MA    1 Season
# 4       s83  TV Show                 Lucifer          2021  TV-14   6 Seasons
# ..      ...      ...                     ...           ...    ...         ...
# 96    s3118  TV Show             The Witcher          2019  TV-MA    1 Season
# 97    s3130  TV Show    Crash Landing on You          2019  TV-14    1 Season
# 98    s4407  TV Show       The Queen of Flow          2018  TV-MA    1 Season
# 99    s6807  TV Show                 Friends          2003  TV-14  10 Seasons
# 100   s7913    Movie                S.W.A.T.          2003  PG-13     117 min
#
#                                              listed_in
# 0                   TV Dramas, TV Horror, TV Mysteries
# 1    International TV Shows, TV Action & Adventure,...
# 2    British TV Shows, International TV Shows, TV C...
# 3      International TV Shows, TV Dramas, TV Thrillers
# 4               Crime TV Shows, TV Comedies, TV Dramas
# ..                                                 ...
# 96   International TV Shows, TV Action & Adventure,...
# 97   International TV Shows, Korean TV Shows, Roman...
# 98   Crime TV Shows, International TV Shows, Spanis...
# 99                      Classic & Cult TV, TV Comedies
# 100                                 Action & Adventure
#
# [101 rows x 7 columns]

# %%
ratings_ages = {'TV-PG': 'Older Kids', 'TV-MA': 'Adults', 'TV-Y7-FV': 'Older Kids',
                  'TV-Y7': 'Older Kids', 'TV-14': 'Teens', 'R': 'Adults', 'TV-Y': 'Kids',
                  'NR': 'Adults', 'PG-13': 'Teens', 'TV-G': 'Kids', 'PG': 'Older Kids',
                  'G': 'Kids', 'UR': 'Adults', 'NC-17': 'Adults'}
