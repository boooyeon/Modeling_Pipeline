# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# # 실습 내용
#
# - 우선 머신러닝 모델링을 위한 코딩을 할 수 있어야 합니다.
# - 코딩 내용을 자세히 알지 못해도 무작정 코딩을 진행해봅니다.
# - Iris 데이터를 대상으로 모델링를 진행합니다.
# - DecisionTree 알고리즘을 사용합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 **라이브러리**와 대상 **데이터**를 가져와 이후 과정을 준비합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_11.png?raw=true" width=700 align="left"/>

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/Jangrae/csv/master/iris.csv'
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 **충분히 이해**할 수 있도록 다양한 **탐색** 과정을 수행합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_12.png?raw=true" width=700 align="left"/>

# %%
# 상위 몇 개 행 확인
data.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 하위 몇 개 행 확인
data.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# 변수 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# 기초통계량 확인
data.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Target 변수 값 분포 확인
data['Species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %%
# Target 변수 값 분포 확인 1
sns.countplot(x=data['Species'])
plt.show()

# %%
# 상관관계 확인
data.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
# 상관관계 시각화
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# # 3.데이터 준비
#
# - **전처리** 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_13.png?raw=true" width=700 align="left"/>

# %% [markdown]
# **1) x, y 분리**

# %%
# target 확인
target = 'Species'

# 데이터 분리
x = data.drop(target, axis=1)
y = data[target] # y = data.loc[:, target]

# %% [markdown]
# **2) 학습용, 평가용 데이터 분리**

# %%
# 모듈 불러오기
from sklearn.model_selection import train_test_split

# 7:3으로 분리
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2022)

# %% [markdown]
# # 4.모델링
#
# - 본격적으로 모델을 **선언**하고 **학습**하고 **평가**하는 과정을 진행합니다.
# - 우선 **회귀** 문제인지 **분류** 문제인지 명확히 구분합니다.

# %% [markdown]
# <img src = "https://github.com/Jangrae/img/blob/master/code_14.png?raw=true" width=700 align="left"/>

# %% [markdown]
# - 품종 예측 → **<font color='red'>분류 문제</font>**
# - 알고리즘: DecisionTreeClassifier
# - 평가지표: accuracy_score

# %%
# 1단계: 불러오기
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
# 2단계: 선언하기
model = DecisionTreeClassifier(random_state=2022)

# %%
# 3단계: 학습하기
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=2022)

# %%
# 4단계: 예측하기
y_pred = model.predict(x_test)

# %%
# 5단계 평가하기
accuracy_score(y_test, y_pred)
# Out:
# 0.9333333333333333

# %%
import matplotlib.pyplot as plt
from sklearn import tree


# 모듈 불러오기
from sklearn.datasets import load_iris

# 데이터 가져오기
iris = load_iris()

plt.figure(figsize=(20,15))
tree.plot_tree(model, 
               class_names=iris.target_names,
               feature_names=iris.feature_names,
               impurity=True, filled=True,
               rounded=True)
# Out:
# [Text(0.4444444444444444, 0.9285714285714286, 'petal width (cm) <= 0.75\ngini = 0.666\nsamples = 105\nvalue = [36, 35, 34]\nclass = setosa'),
#  Text(0.3333333333333333, 0.7857142857142857, 'gini = 0.0\nsamples = 36\nvalue = [36, 0, 0]\nclass = setosa'),
#  Text(0.5555555555555556, 0.7857142857142857, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 69\nvalue = [0, 35, 34]\nclass = versicolor'),
#  Text(0.3333333333333333, 0.6428571428571429, 'petal length (cm) <= 5.35\ngini = 0.149\nsamples = 37\nvalue = [0, 34, 3]\nclass = versicolor'),
#  Text(0.2222222222222222, 0.5, 'sepal length (cm) <= 4.95\ngini = 0.105\nsamples = 36\nvalue = [0, 34, 2]\nclass = versicolor'),
#  Text(0.1111111111111111, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.3333333333333333, 0.35714285714285715, 'sepal width (cm) <= 2.25\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]\nclass = versicolor'),
#  Text(0.2222222222222222, 0.21428571428571427, 'petal width (cm) <= 1.25\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(0.1111111111111111, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(0.3333333333333333, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.4444444444444444, 0.21428571428571427, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = versicolor'),
#  Text(0.4444444444444444, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(0.7777777777777778, 0.6428571428571429, 'petal length (cm) <= 4.85\ngini = 0.061\nsamples = 32\nvalue = [0, 1, 31]\nclass = virginica'),
#  Text(0.6666666666666666, 0.5, 'sepal length (cm) <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(0.5555555555555556, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(0.7777777777777778, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(0.8888888888888888, 0.5, 'gini = 0.0\nsamples = 29\nvalue = [0, 0, 29]\nclass = virginica')]
